# %%
import os
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score
# Out:
# C:\Users\rishabh\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
os.chdir("C:/Users/rishabh/Desktop/TCS_Project")

# %%
# Reading the excel file

# %%
master_quote = pd.read_excel("master_quotes-09RNH_fn.xlsx", encoding='utf-8')

# %%
master_quote.shape # getting the shape of data
# Out:
# (230, 128)

# %%
# Dropping all the columns with NaN values

# %%
master_quote = master_quote.dropna(axis=1, how = 'all', inplace = False)

# %%
master_quote
# Out:
#          ROW_ID CRDT_CHK_PASSD_FLG                      QUOTE_NAME  \
# 0    8SIA-7JWNO                  Y       Temp Promo Reconfig Quote
# 1    8SIA-7H83T                  Y  GUEST_Cart_04/25/2008 11:51:44
# 2    8SIA-7IW8K                  Y  GUEST_Cart_04/30/2008 17:30:07
# 3    8SIA-7IW74                  Y  GUEST_Cart_04/30/2008 16:14:18
# 4    8SIA-7IRXR                  Y  GUEST_Cart_04/30/2008 13:01:04
# 5    8SIA-7PKP0                  Y  GUEST_Cart_05/14/2008 13:43:45
# 6    9SIA-83KIG                  Y                      Test Quote
# 7    9SIA-80YUR                  Y                      9SIA-80YUR
# 8    8SIA-7N9OC                  Y  GUEST_Cart_05/09/2008 10:36:51
# 9    8SIA-7LPUT                  Y  GUEST_Cart_05/07/2008 12:48:13
# 10   8SIA-7LPKG                  Y  GUEST_Cart_05/07/2008 12:31:16
# 11   8SIA-79PA1                  Y  GUEST_Cart_04/04/2008 13:54:00
# 12   8SIA-7JWGX                  Y  GUEST_Cart_05/02/2008 11:37:02
# 13   8SIA-7NA3T                  Y  GUEST_Cart_05/09/2008 12:32:41
# 14   8SIA-7NE0D                  Y  GUEST_Cart_05/09/2008 15:50:18
# 15   8SIA-7FKT7                  Y  GUEST_Cart_04/21/2008 15:21:11
# 16   8SIA-7PWLT                  Y  GUEST_Cart_05/14/2008 21:14:34
# 17   8SIA-7OZO4                  Y  GUEST_Cart_05/13/2008 13:39:30
# 18   8SIA-7OZJF                  Y  GUEST_Cart_05/13/2008 13:25:49
# 19   8SIA-7NZ91                  Y  GUEST_Cart_05/12/2008 09:16:56
# 20   8SIA-7NZ2R                  Y       Temp Promo Reconfig Quote
# 21   8SIA-7N9VD                  Y  GUEST_Cart_05/09/2008 11:18:25
# 22   8SIA-7O5DP                  Y  GUEST_Cart_05/12/2008 15:09:09
# 23   8SIA-7JJMD                  Y  GUEST_Cart_05/01/2008 13:23:13
# 24   8SIA-7NDS6                  Y  GUEST_Cart_05/09/2008 14:38:03
# 25   8SIA-7A4WF                  Y  GUEST_Cart_04/07/2008 11:05:40
# 26   9SIA-98G21                  Y                      9SIA-98G21
# 27   9SIA-8FZNA                  Y                              Q2
# 28   9SIA-8FXTL                  Y                              Q1
# 29   9SIA-873B1                  Y                      9SIA-873B1
# ..          ...                ...                             ...
# 200   1SIA-U6DK                  Y                       1SIA-U6DE
# 201      1-K4MN                  Y                          1-K4MN
# 202      1-L23P                  Y                          1-L23P
# 203      1-M801                  Y                          1-M801
# 204      1-PD9T                  Y                          1-PD9T
# 205      1-PDKX                  Y                          1-PDKX
# 206    1LS-AGPN                  Y            Janus Open MRI Quote
# 207    1LS-AGRO                  Y           Angioplasty Catheters
# 208   1SIA-U1QW                  Y                       1SIA-U1QQ
# 209   1SIA-U1SE                  Y                       1SIA-U1S8
# 210   1SIA-U6EG                  Y                       1SIA-U6EA
# 211      1-JYZD                  Y                          1-JYZD
# 212   1SIA-UE4U                  Y                       1SIA-UE4O
# 213      1-EKX0                  Y                          1-EKX0
# 214   1SIA-UE3C                  Y                       1SIA-UE36
# 215      1-JIY1                  Y                          1-JIY1
# 216      1-JH2X                  Y                          1-JH2X
# 217      1-GZK8                  Y                          1-GZK8
# 218      1-EL8G                  Y                          1-EL8G
# 219      1-EL8D                  Y                          1-EL8D
# 220      1-EKX3                  Y                          1-EKX3
# 221      1-EKWS                  Y                          1-EKWS
# 222    1LS-AUH3                  Y           100 5 French Catheter
# 223    1LS-AUFQ                  Y               5 French Catheter
# 224    1LS-AUAE                  Y               7 French Catheter
# 225    1LS-ATY8                  Y             Catheter Reorder #2
# 226    1LS-ATX4                  Y                Catheter Reorder
# 227    1LS-AJI4                  Y                  AENA Catheters
# 228    1LS-AH88                  Y            Cardiology Catheters
# 229      1-EKX6                  Y                          1-EKX6
#
#     NEW_PROD_GROUP_FLG OPEN_ORDER_FLG PRD_GRP_DIRTY_FLG   QUOTE_NUM  \
# 0                    Y              N                 N  8SIA-7JWNO
# 1                    Y              N                 N  8SIA-7H83T
# 2                    Y              N                 N  8SIA-7IW8K
# 3                    Y              N                 N  8SIA-7IW74
# 4                    Y              N                 N  8SIA-7IRXR
# 5                    Y              N                 N  8SIA-7PKP0
# 6                    Y              N                 N  9SIA-83KIG
# 7                    Y              N                 N  9SIA-80YUR
# 8                    Y              N                 N  8SIA-7N9OC
# 9                    Y              N                 N  8SIA-7LPUT
# 10                   Y              N                 N  8SIA-7LPKG
# 11                   Y              N                 N  8SIA-79PA1
# 12                   Y              N                 N  8SIA-7JWGX
# 13                   Y              N                 N  8SIA-7NA3T
# 14                   Y              N                 N  8SIA-7NE0D
# 15                   Y              N                 N  8SIA-7FKT7
# 16                   Y              N                 N  8SIA-7PWLT
# 17                   Y              N                 N  8SIA-7OZO4
# 18                   Y              N                 N  8SIA-7OZJF
# 19                   Y              N                 N  8SIA-7NZ91
# 20                   Y              N                 N  8SIA-7NZ2R
# 21                   Y              N                 N  8SIA-7N9VD
# 22                   Y              N                 N  8SIA-7O5DP
# 23                   Y              N                 N  8SIA-7JJMD
# 24                   Y              N                 N  8SIA-7NDS6
# 25                   Y              N                 N  8SIA-7A4WF
# 26                   Y              N                 N  9SIA-98G21
# 27                   Y              N                 N  9SIA-8FZNA
# 28                   Y              N                 N  9SIA-8FXTL
# 29                   Y              N                 N  9SIA-873B1
# ..                 ...            ...               ...         ...
# 200                  Y              N                 N   1SIA-U6DK
# 201                  Y              N                 N      1-K4MN
# 202                  Y              N                 N      1-L23P
# 203                  Y              N                 N      1-M801
# 204                  Y              N                 N      1-PD9T
# 205                  Y              N                 N      1-PDKX
# 206                  Y              N                 N    1LS-AGPN
# 207                  Y              N                 N    1LS-AGRO
# 208                  Y              N                 N   1SIA-U1QW
# 209                  Y              N                 N   1SIA-U1SE
# 210                  Y              N                 N   1SIA-U6EG
# 211                  Y              N                 N      1-JYZD
# 212                  Y              N                 N   1SIA-UE4U
# 213                  Y              N                 N      1-EKX0
# 214                  Y              N                 N   1SIA-UE3C
# 215                  Y              N                 N      1-JIY1
# 216                  Y              N                 N      1-JH2X
# 217                  Y              N                 N      1-GZK8
# 218                  Y              N                 N      1-EL8G
# 219                  Y              N                 N      1-EL8D
# 220                  Y              N                 N      1-EKX3
# 221                  Y              N                 N      1-EKWS
# 222                  Y              N                 N    1LS-AUH3
# 223                  Y              N                 N    1LS-AUFQ
# 224                  Y              N                 N    1LS-AUAE
# 225                  Y              N                 N    1LS-ATY8
# 226                  Y              N                 N    1LS-ATX4
# 227                  Y              N                 N    1LS-AJI4
# 228                  Y              N                 N    1LS-AH88
# 229                  Y              N                 N      1-EKX6
#
#     TEMPLATE_FLG TEST_QUOTE_FLG CURCY_CD     ...      QUOTE_SUB_TYPE_CD  \
# 0              N              N      USD     ...                    NaN
# 1              N              N      USD     ...                    NaN
# 2              N              N      USD     ...                    NaN
# 3              N              N      USD     ...                    NaN
# 4              N              N      USD     ...                    NaN
# 5              N              N      USD     ...                    NaN
# 6              N              N      USD     ...                    NaN
# 7              N              N      USD     ...                    NaN
# 8              N              N      USD     ...                    NaN
# 9              N              N      USD     ...                    NaN
# 10             N              N      USD     ...                    NaN
# 11             N              N      USD     ...                    NaN
# 12             N              N      USD     ...                    NaN
# 13             N              N      USD     ...                    NaN
# 14             N              N      USD     ...                    NaN
# 15             N              N      USD     ...                    NaN
# 16             N              N      USD     ...                    NaN
# 17             N              N      USD     ...                    NaN
# 18             N              N      USD     ...                    NaN
# 19             N              N      USD     ...                    NaN
# 20             N              N      USD     ...                    NaN
# 21             N              N      USD     ...                    NaN
# 22             N              N      USD     ...                    NaN
# 23             N              N      USD     ...                    NaN
# 24             N              N      USD     ...                    NaN
# 25             N              N      USD     ...                    NaN
# 26             N              N      USD     ...                    NaN
# 27             N              N      USD     ...                    NaN
# 28             N              N      USD     ...                    NaN
# 29             N              Y      USD     ...                    NaN
# ..           ...            ...      ...     ...                    ...
# 200            N              N      USD     ...                    NaN
# 201            N              N      USD     ...                    NaN
# 202            N              N      USD     ...                    NaN
# 203            N              N      USD     ...                    NaN
# 204            N              N      USD     ...                    NaN
# 205            N              N      USD     ...                    NaN
# 206            N              N      USD     ...                    NaN
# 207            N              N      USD     ...                    NaN
# 208            N              N      USD     ...                    NaN
# 209            N              N      USD     ...                    NaN
# 210            N              N      USD     ...                    NaN
# 211            N              N      USD     ...                    NaN
# 212            N              N      USD     ...                    NaN
# 213            N              N      USD     ...                    NaN
# 214            N              N      USD     ...                    NaN
# 215            N              N      USD     ...                    NaN
# 216            N              N      USD     ...                    NaN
# 217            N              N      USD     ...                    NaN
# 218            N              N      USD     ...                    NaN
# 219            N              N      USD     ...                    NaN
# 220            N              N      USD     ...                    NaN
# 221            N              N      USD     ...                    NaN
# 222            N              N      USD     ...                    NaN
# 223            N              N      USD     ...                    NaN
# 224            N              N      USD     ...                    NaN
# 225            N              N      USD     ...                    NaN
# 226            N              N      USD     ...                    NaN
# 227            N              N      USD     ...                    NaN
# 228            N              N      USD     ...                    NaN
# 229            N              N      USD     ...                    NaN
#
#            QUOTE_TYPE  SALES_REP_POSTN_ID  SERV_ACCNT_ID SHIP_ZIPCODE  \
# 0           ABO Quote              0-5220            NaN          NaN
# 1           Quotation              0-5220            NaN          NaN
# 2           Quotation              0-5220            NaN          NaN
# 3           Quotation              0-5220            NaN          NaN
# 4           Quotation              0-5220            NaN          NaN
# 5           Quotation              0-5220            NaN          NaN
# 6           Quotation              0-5220            NaN          NaN
# 7           Quotation              0-5220         1-5GZE      10050.0
# 8           Quotation              0-5220            NaN          NaN
# 9           Quotation              0-5220            NaN          NaN
# 10          Quotation              0-5220            NaN          NaN
# 11          Quotation              0-5220            NaN          NaN
# 12          Quotation              0-5220            NaN          NaN
# 13          Quotation              0-5220            NaN          NaN
# 14          Quotation              0-5220            NaN          NaN
# 15          Quotation              0-5220            NaN          NaN
# 16          Quotation              0-5220            NaN          NaN
# 17          Quotation              0-5220            NaN          NaN
# 18          Quotation              0-5220            NaN          NaN
# 19          Quotation              0-5220            NaN          NaN
# 20          ABO Quote              0-5220            NaN          NaN
# 21          Quotation              0-5220            NaN          NaN
# 22          Quotation              0-5220            NaN          NaN
# 23          Quotation              0-5220            NaN          NaN
# 24          Quotation              0-5220            NaN          NaN
# 25          Quotation              0-5220            NaN          NaN
# 26          Quotation              0-5220         1-63Q9      94510.0
# 27          Quotation              0-5220     3SIA-2OJZ1      60626.0
# 28          Quotation              0-5220     3SIA-2OJZ1      60626.0
# 29          Quotation              0-5220     9SIA-8738N          NaN
# ..                ...                 ...            ...          ...
# 200  PC Like for Like             0-57T1J            NaN          NaN
# 201         Quotation              0-5220            NaN          NaN
# 202         Quotation              0-5220            NaN          NaN
# 203         Quotation             0-57T1J            NaN          NaN
# 204         Quotation             0-57T1J            NaN          NaN
# 205         Quotation             0-57T1J            NaN          NaN
# 206         Quotation              1-1KN3            NaN          NaN
# 207         Quotation              1-1KN3            NaN      12211.0
# 208     PC Comparison             0-57T1J            NaN          NaN
# 209  PC Like for Like             0-57T1J            NaN          NaN
# 210     PC Comparison             0-57T1J            NaN          NaN
# 211         Quotation              0-5220            NaN          NaN
# 212  PC Like for Like             0-57T1J            NaN          NaN
# 213         Quotation              1-CSO9            NaN          NaN
# 214     PC Comparison             0-57T1J            NaN          NaN
# 215   Persistent Cart             0-57T1J            NaN          NaN
# 216   Persistent Cart             0-57T1J            NaN          NaN
# 217         Quotation              0-5220            NaN          NaN
# 218         Quotation              1-CSO9            NaN          NaN
# 219         Quotation              1-CSO9            NaN          NaN
# 220         Quotation              1-CSO9            NaN          NaN
# 221         Quotation              1-CSO9            NaN          NaN
# 222         Quotation              1-1KN3            NaN      12211.0
# 223         Quotation              1-1KN3            NaN      12211.0
# 224         Quotation              1-1KN3            NaN      12211.0
# 225         Quotation              1-1KN3            NaN      12211.0
# 226         Quotation              1-1KN3            NaN      12211.0
# 227         Quotation              1-1KN3            NaN      12211.0
# 228         Quotation              1-1KN3            NaN      12211.0
# 229         Quotation              1-CSO9            NaN          NaN
#
#        SHIP_CONTACT              SHIP_ACCOUNT  SHIP_PER_ZIPCODE       STAT_CD  \
# 0               NaN                       NaN               NaN          Lost
# 1               NaN                       NaN               NaN          Lost
# 2               NaN                       NaN               NaN          Lost
# 3               NaN                       NaN               NaN          Lost
# 4               NaN                       NaN               NaN          Lost
# 5               NaN                       NaN               NaN          Lost
# 6               NaN                       NaN               NaN          Lost
# 7     Steven Gaines    AG Edwards & Sons, Inc               NaN          Lost
# 8               NaN                       NaN               NaN          Lost
# 9               NaN                       NaN               NaN          Lost
# 10              NaN                       NaN               NaN          Lost
# 11              NaN                       NaN               NaN          Lost
# 12              NaN                       NaN               NaN          Lost
# 13              NaN                       NaN               NaN          Lost
# 14              NaN                       NaN               NaN          Lost
# 15              NaN                       NaN               NaN          Lost
# 16              NaN                       NaN               NaN          Lost
# 17              NaN                       NaN               NaN          Lost
# 18              NaN                       NaN               NaN          Lost
# 19              NaN                       NaN               NaN          Lost
# 20              NaN                       NaN               NaN          Lost
# 21              NaN                       NaN               NaN          Lost
# 22              NaN                       NaN               NaN          Lost
# 23              NaN                       NaN               NaN          Lost
# 24              NaN                       NaN               NaN          Lost
# 25              NaN                       NaN               NaN          Lost
# 26   Avo Sarkissian                     3 Com               NaN          Lost
# 27              NaN                      3Com               NaN          Lost
# 28              NaN                      3Com               NaN          Lost
# 29              NaN                       NaN               NaN          Lost
# ..              ...                       ...               ...           ...
# 200             NaN                       NaN               NaN  Order Placed
# 201             NaN                       NaN               NaN          Lost
# 202             NaN                       NaN               NaN          Lost
# 203             NaN                       NaN               NaN          Lost
# 204             NaN                       NaN               NaN          Lost
# 205             NaN                       NaN               NaN          Lost
# 206   John Ashapiro   Albany Neurology Center               NaN          Lost
# 207   Jill Albright   Albany General Hospital               NaN  Order Placed
# 208             NaN                       NaN               NaN  Order Placed
# 209             NaN                       NaN               NaN          Lost
# 210             NaN                       NaN               NaN          Lost
# 211             NaN                       NaN               NaN          Lost
# 212             NaN                       NaN               NaN  Order Placed
# 213             NaN                       NaN               NaN          Lost
# 214             NaN                       NaN               NaN          Lost
# 215             NaN                       NaN               NaN          Lost
# 216             NaN                       NaN               NaN          Lost
# 217             NaN  McMoney Asset Management               NaN          Lost
# 218             NaN                       NaN               NaN          Lost
# 219             NaN                       NaN               NaN          Lost
# 220             NaN                       NaN               NaN          Lost
# 221             NaN                       NaN               NaN          Lost
# 222   Jill Albright   Albany General Hospital               NaN          Lost
# 223   Jill Albright   Albany General Hospital               NaN          Lost
# 224   Jill Albright   Albany General Hospital               NaN  Order Placed
# 225   Jill Albright   Albany General Hospital               NaN  Order Placed
# 226   Jill Albright   Albany General Hospital               NaN  Order Placed
# 227   Jill Albright   Albany General Hospital               NaN          Lost
# 228   Jill Albright   Albany General Hospital               NaN  Order Placed
# 229             NaN                       NaN               NaN          Lost
#
#     TARGET_OU_ID
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7         1-5GZE
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26        1-63Q9
# 27    3SIA-2OJZ1
# 28    3SIA-2OJZ1
# 29    9SIA-8738N
# ..           ...
# 200          NaN
# 201          NaN
# 202          NaN
# 203          NaN
# 204          NaN
# 205          NaN
# 206     1LS-9XKU
# 207        1-34Z
# 208          NaN
# 209          NaN
# 210          NaN
# 211          NaN
# 212          NaN
# 213          NaN
# 214          NaN
# 215          NaN
# 216          NaN
# 217       1-FU2C
# 218          NaN
# 219          NaN
# 220          NaN
# 221          NaN
# 222        1-34Z
# 223        1-34Z
# 224        1-34Z
# 225        1-34Z
# 226        1-34Z
# 227        1-34Z
# 228        1-34Z
# 229          NaN
#
# [230 rows x 50 columns]

# %%
# Summing up all missing values from each column in the dataframe

missing_val_quote = pd.DataFrame(master_quote.isna().sum())

# %%
missing_val_quote = missing_val_quote.reset_index()

# %%
missing_val_quote
# Out:
#                  index    0
# 0               ROW_ID    0
# 1   CRDT_CHK_PASSD_FLG    0
# 2           QUOTE_NAME    0
# 3   NEW_PROD_GROUP_FLG    0
# 4       OPEN_ORDER_FLG    0
# 5    PRD_GRP_DIRTY_FLG    0
# 6            QUOTE_NUM    0
# 7         TEMPLATE_FLG    0
# 8       TEST_QUOTE_FLG    0
# 9             CURCY_CD    0
# 10          ACTIVE_FLG    4
# 11         CG_FCST_AMT  187
# 12       DISCNT_AMT_RC  187
# 13      DISCNT_PERCENT  228
# 14              DUE_DT   46
# 15          EFF_END_DT   14
# 16        EFF_START_DT   21
# 17            HIST_AMT  187
# 18       QUOTE_EXCH_DT   59
# 19           STATUS_DT  164
# 20             TGT_AMT  187
# 21      BILL_PERIOD_CD  220
# 22     BILL_PROFILE_ID  221
# 23          BL_ACCT_ID  190
# 24        BILL_ZIPCODE  201
# 25        BILL_CONTACT  204
# 26        BILL_ACCOUNT  186
# 27      BL_PER_ADDR_ID  227
# 28      CMPND_PROD_NUM   48
# 29             CONTACT  180
# 30         CUSTOMER_ID  178
# 31       CUST_ACCNT_ID  197
# 32           DESC_TEXT   89
# 33     DISPLAY_TYPE_CD  147
# 34       LOY_MEMBER_ID  228
# 35             OPTY_ID  221
# 36     PAYMENT_TERM_ID  218
# 37           PAY_OU_ID  210
# 38          PRI_LST_ID   35
# 39       PR_PAYMENT_ID  196
# 40   QUOTE_SUB_TYPE_CD  224
# 41          QUOTE_TYPE    0
# 42  SALES_REP_POSTN_ID    0
# 43       SERV_ACCNT_ID  190
# 44        SHIP_ZIPCODE  198
# 45        SHIP_CONTACT  177
# 46        SHIP_ACCOUNT  186
# 47    SHIP_PER_ZIPCODE  216
# 48             STAT_CD    0
# 49        TARGET_OU_ID  165

# %%
missing_val_quote = missing_val_quote.rename(columns = {'index': 'columns', 0: 'missing_val' })

# %%
# Finding the Percentage of the missing values in each column

missing_val_quote['missing_val'] = (missing_val_quote['missing_val']/len(master_quote))*100

# %%
# sorting the missing value percentage in descending order

# %%
missing_val_quote = missing_val_quote.sort_values('missing_val', ascending = False).reset_index(drop = True)

# %%
missing_val_quote
# Out:
#                columns  missing_val
# 0       DISCNT_PERCENT    99.130435
# 1        LOY_MEMBER_ID    99.130435
# 2       BL_PER_ADDR_ID    98.695652
# 3    QUOTE_SUB_TYPE_CD    97.391304
# 4              OPTY_ID    96.086957
# 5      BILL_PROFILE_ID    96.086957
# 6       BILL_PERIOD_CD    95.652174
# 7      PAYMENT_TERM_ID    94.782609
# 8     SHIP_PER_ZIPCODE    93.913043
# 9            PAY_OU_ID    91.304348
# 10        BILL_CONTACT    88.695652
# 11        BILL_ZIPCODE    87.391304
# 12        SHIP_ZIPCODE    86.086957
# 13       CUST_ACCNT_ID    85.652174
# 14       PR_PAYMENT_ID    85.217391
# 15       SERV_ACCNT_ID    82.608696
# 16          BL_ACCT_ID    82.608696
# 17         CG_FCST_AMT    81.304348
# 18       DISCNT_AMT_RC    81.304348
# 19            HIST_AMT    81.304348
# 20             TGT_AMT    81.304348
# 21        BILL_ACCOUNT    80.869565
# 22        SHIP_ACCOUNT    80.869565
# 23             CONTACT    78.260870
# 24         CUSTOMER_ID    77.391304
# 25        SHIP_CONTACT    76.956522
# 26        TARGET_OU_ID    71.739130
# 27           STATUS_DT    71.304348
# 28     DISPLAY_TYPE_CD    63.913043
# 29           DESC_TEXT    38.695652
# 30       QUOTE_EXCH_DT    25.652174
# 31      CMPND_PROD_NUM    20.869565
# 32              DUE_DT    20.000000
# 33          PRI_LST_ID    15.217391
# 34        EFF_START_DT     9.130435
# 35          EFF_END_DT     6.086957
# 36          ACTIVE_FLG     1.739130
# 37           QUOTE_NUM     0.000000
# 38             STAT_CD     0.000000
# 39          QUOTE_NAME     0.000000
# 40  NEW_PROD_GROUP_FLG     0.000000
# 41      OPEN_ORDER_FLG     0.000000
# 42   PRD_GRP_DIRTY_FLG     0.000000
# 43  CRDT_CHK_PASSD_FLG     0.000000
# 44  SALES_REP_POSTN_ID     0.000000
# 45          QUOTE_TYPE     0.000000
# 46        TEMPLATE_FLG     0.000000
# 47      TEST_QUOTE_FLG     0.000000
# 48            CURCY_CD     0.000000
# 49              ROW_ID     0.000000

# %%
# Using for loop to drop the values having more than 60% null values

# %%
count = 0

for column in missing_val_quote['columns']:
    if count <= 28:
        print(column)   
        master_quote.drop(column,axis = 1,inplace = True)
        count += 1
     
    else:
        break
# Out:
# DISCNT_PERCENT
# LOY_MEMBER_ID
# BL_PER_ADDR_ID
# QUOTE_SUB_TYPE_CD
# OPTY_ID
# BILL_PROFILE_ID
# BILL_PERIOD_CD
# PAYMENT_TERM_ID
# SHIP_PER_ZIPCODE
# PAY_OU_ID
# BILL_CONTACT
# BILL_ZIPCODE
# SHIP_ZIPCODE
# CUST_ACCNT_ID
# PR_PAYMENT_ID
# SERV_ACCNT_ID
# BL_ACCT_ID
# CG_FCST_AMT
# DISCNT_AMT_RC
# HIST_AMT
# TGT_AMT
# BILL_ACCOUNT
# SHIP_ACCOUNT
# CONTACT
# CUSTOMER_ID
# SHIP_CONTACT
# TARGET_OU_ID
# STATUS_DT
# DISPLAY_TYPE_CD

# %%
master_quote.drop("ROW_ID",axis = 1,inplace = True)

# %%
master_quote.shape
# Out:
# (230, 20)

# %%
# Imputing the missing values with mode

# %%
for column in list(master_quote.columns):
    master_quote[column].fillna(master_quote[column].mode()[0], inplace = True)

# %%
# checking the percentage of "Lost" in STAT_CD column

master_quote_label = pd.DataFrame(master_quote.iloc[:,-1])
(len(master_quote_label.loc[master_quote_label["STAT_CD"]=="Lost"])/len(master_quote_label))*100
# 86.521
# Out:
# 86.52173913043478

# %%
master_quote_features = master_quote.iloc[:,:-1]

# %%
# Dropping the columns still having null values

df_no_date = master_quote_features.drop(["DUE_DT","EFF_END_DT","EFF_START_DT","QUOTE_EXCH_DT"],axis = 1)

# %%
quote_clean = df_no_date.join(master_quote_label)

# %%
quote_clean.to_csv("quote_clean.csv", index = False)

# %%
# Encoding the categorical values

df_no_date = pd.get_dummies(df_no_date)

# %%
# Joining the features with Target Column
df_no_date = df_no_date.join(master_quote_label.iloc[:,-1])

# %%
df_no_date.shape
# Out:
# (230, 811)

# %%
# Splitting the data into test and train

# %%
Xd_train, Xd_test, yd_train, yd_test = train_test_split(df_no_date.drop(['STAT_CD'], axis=1), df_no_date['STAT_CD'],test_size = .4,random_state=12)

# %%
sm = SMOTE(random_state=12, ratio = 1.0)

# %%
# Fitting the train data into the SMOTE classifier to get the the equal proportion of target variable class

Xd_train_res, yd_train_res = sm.fit_sample(Xd_train, yd_train)
# Out:
# C:\Users\rishabh\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# checking the ratio of "Lost" and "Order Placed"

len(pd.DataFrame(yd_train_res).loc[pd.DataFrame(yd_train_res)[0]== "Lost"])/len(pd.DataFrame(yd_train_res).loc[pd.DataFrame(yd_train_res)[0] != "Lost"])
# Out:
# 1.0

# %%
# Using the Random Forest Classifier, fitting the model into the training dataset

clf_rf = RandomForestClassifier(n_estimators = 100, random_state = 12).fit(Xd_train_res, yd_train_res)

# %%
# Predict the test data

test_prediction = clf_rf.predict(Xd_test)

# %%
test_prediction
# Out:
# array(['Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Order Placed',
#        'Lost', 'Order Placed', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost',
#        'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost',
#        'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost',
#        'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost',
#        'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost',
#        'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Order Placed', 'Lost',
#        'Order Placed', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost',
#        'Lost', 'Lost', 'Lost', 'Lost', 'Order Placed', 'Lost', 'Lost',
#        'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost',
#        'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost',
#        'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost', 'Lost',
#        'Lost'], dtype=object)

# %%
accuracy_score(yd_test, test_prediction)
# Out:
# 0.9239130434782609

# %%
# Creating the matrix to check the accuracy

CM = pd.crosstab(yd_test, test_prediction)

# %%
CM
# Out:
# col_0         Lost  Order Placed
# STAT_CD
# Lost            81             1
# Order Placed     6             4

# %%
TN = CM.iloc[0,0]
FN = CM.iloc[1,0]
TP = CM.iloc[1,1]
FP = CM.iloc[0,1]

# %%
#accuracy_score(y_test, y_pred)*100
((TP+TN)*100)/(TP+TN+FP+FN)
# Out:
# 92.3913043478261

# %%
#False Negative rate 
(FN*100)/(FN+TP)
# Out:
# 60.0

# %% [markdown]
# # Model Serialization

# %%
import pickle as pickle
import requests,json
from sklearn.externals import joblib

# %%
# pickle.dump(clf_rf,open("clf_rf.pkl","wb"))

# %%
# my_random_forest = pickle.load(open("clf_rf.pkl","rb"))

# %%
# my_random_forest

# %%
# accuracy_score(yd_test, my_random_forest.predict(Xd_test))

# %%
# url = "http://localhost:12345/api"
# data = json.dumps({})

# %%
joblib.dump(clf_rf,"model.pkl")
# Out:
# ['model.pkl']

# %%
rf = joblib.load("model.pkl")

# %%
accuracy_score(yd_test, rf.predict(Xd_test))
# Out:
# 0.9239130434782609

# %%
model_columns = list(Xd_train.columns)

# %%
joblib.dump(model_columns,"model_columns.pkl")
# Out:
# ['model_columns.pkl']

# %%
Xd_train.shape
# Out:
# (138, 810)
